# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt 


img=cv2.imread("11.2 smile.jpg.jpg")#bgr format
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)


plt.imshow(img,cmap='gray',interpolation='BICUBIC')#rgb format# color map=cmap
plt.show()
